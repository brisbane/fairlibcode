# %%
import analysis_compass as analysis

# %%
df= analysis.prepare_compass_data()
# Out:
# 0      -1.00
# 1      -1.00
# 2      -1.00
# 3        NaN
# 4        NaN
#         ...
# 7209   -1.00
# 7210   -1.00
# 7211   -1.00
# 7212   -1.00
# 7213   -2.00
# Name: days_b_screening_arrest, Length: 7214, dtype: float64
# 6172
# ...

# %%
df

# %%
import pandas as pd

# %%
import importlib, os, sys

importlib.reload(analysis)
# Out:
# <module 'analysis_compass' from '/home/user/DeepLearning/fairlibcode/compass/analysis_compass.py'>

# %%
        pd.options.display.float_format = '{:,.2f}'.format
        dataset_base_dir = "compass_data/"
        dataset_file_name = 'compas-scores-two-years.csv'
        file_path = os.path.join(dataset_base_dir,dataset_file_name)
        temp_df = pd.read_csv(file_path)

# %%
# %matplotlib
temp_df.count
# Out:
# Using matplotlib backend: TkAgg
# <bound method DataFrame.count of          id                 name      first         last  \
# 0         1     miguel hernandez     miguel    hernandez
# 1         3          kevon dixon      kevon        dixon
# 2         4             ed philo         ed        philo
# 3         5          marcu brown      marcu        brown
# 4         6   bouthy pierrelouis     bouthy  pierrelouis
# ...     ...                  ...        ...          ...
# 7209  10996        steven butler     steven       butler
# 7210  10997      malcolm simmons    malcolm      simmons
# 7211  10999      winston gregory    winston      gregory
# 7212  11000          farrah jean     farrah         jean
# 7213  11001  florencia sanmartin  florencia    sanmartin
#
#      compas_screening_date     sex         dob  age          age_cat  \
# 0               2013-08-14    Male  1947-04-18   69  Greater than 45
# 1               2013-01-27    Male  1982-01-22   34          25 - 45
# ...

# %%
temp_df[(temp_df['is_recid'] ==1 ) | (temp_df['is_recid'] ==0) ]
# Out:
#          id                 name      first         last  \
# 0         1     miguel hernandez     miguel    hernandez
# 1         3          kevon dixon      kevon        dixon
# 2         4             ed philo         ed        philo
# 3         5          marcu brown      marcu        brown
# 4         6   bouthy pierrelouis     bouthy  pierrelouis
# ...     ...                  ...        ...          ...
# 7209  10996        steven butler     steven       butler
# 7210  10997      malcolm simmons    malcolm      simmons
# 7211  10999      winston gregory    winston      gregory
# 7212  11000          farrah jean     farrah         jean
# 7213  11001  florencia sanmartin  florencia    sanmartin
#
#      compas_screening_date     sex         dob  age          age_cat  \
# 0               2013-08-14    Male  1947-04-18   69  Greater than 45
# 1               2013-01-27    Male  1982-01-22   34          25 - 45
# 2               2013-04-14    Male  1991-05-14   24     Less than 25
# ...

# %%
temp_df.columns
# Out:
# Index(['id', 'name', 'first', 'last', 'compas_screening_date', 'sex', 'dob',
#        'age', 'age_cat', 'race', 'juv_fel_count', 'decile_score',
#        'juv_misd_count', 'juv_other_count', 'priors_count',
#        'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_case_number',
#        'c_offense_date', 'c_arrest_date', 'c_days_from_compas',
#        'c_charge_degree', 'c_charge_desc', 'is_recid', 'r_case_number',
#        'r_charge_degree', 'r_days_from_arrest', 'r_offense_date',
#        'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid',
#        'is_violent_recid', 'vr_case_number', 'vr_charge_degree',
#        'vr_offense_date', 'vr_charge_desc', 'type_of_assessment',
#        'decile_score.1', 'score_text', 'screening_date',
#        'v_type_of_assessment', 'v_decile_score', 'v_score_text',
#        'v_screening_date', 'in_custody', 'out_custody', 'priors_count.1',
#        'start', 'end', 'event', 'two_year_recid'],
#       dtype='object')

# %%
temp_df['days_b_screening_arrest'] <= 30
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7209     True
# 7210     True
# 7211     True
# 7212     True
# 7213     True
# Name: days_b_screening_arrest, Length: 7214, dtype: bool

# %%
#filters out around 15%
temp_df2 = temp_df [ (temp_df['days_b_screening_arrest'] <= 30 ) &  (temp_df['days_b_screening_arrest'] >= -30)  ] 
temp_df2.shape[0]
# Out:
# 6172

# %%
temp_df['days_b_screening_arrest'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 7209    False
# 7210    False
# 7211    False
# 7212    False
# 7213    False
# Name: days_b_screening_arrest, Length: 7214, dtype: bool

# %%
((temp_df['days_b_screening_arrest'] <= 30 )== True).count_nonzero()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_18564/3489833109.py in ?()
# ----> 1 ((temp_df['days_b_screening_arrest'] <= 30 )== True).count_nonzero()
#
# ~/miniconda3/envs/pristine/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'count_nonzero'

# %%
temp_df
# Out:
#          id                 name      first         last  \
# 0         1     miguel hernandez     miguel    hernandez
# 1         3          kevon dixon      kevon        dixon
# 2         4             ed philo         ed        philo
# 3         5          marcu brown      marcu        brown
# 4         6   bouthy pierrelouis     bouthy  pierrelouis
# ...     ...                  ...        ...          ...
# 7209  10996        steven butler     steven       butler
# 7210  10997      malcolm simmons    malcolm      simmons
# 7211  10999      winston gregory    winston      gregory
# 7212  11000          farrah jean     farrah         jean
# 7213  11001  florencia sanmartin  florencia    sanmartin
#
#      compas_screening_date     sex         dob  age          age_cat  \
# 0               2013-08-14    Male  1947-04-18   69  Greater than 45
# 1               2013-01-27    Male  1982-01-22   34          25 - 45
# 2               2013-04-14    Male  1991-05-14   24     Less than 25
# ...

# %%
temp_df2[(temp_df2['c_charge_degree']  == "O") ]
# Out:
# Empty DataFrame
# Columns: [id, name, first, last, compas_screening_date, sex, dob, age, age_cat, race, juv_fel_count, decile_score, juv_misd_count, juv_other_count, priors_count, days_b_screening_arrest, c_jail_in, c_jail_out, c_case_number, c_offense_date, c_arrest_date, c_days_from_compas, c_charge_degree, c_charge_desc, is_recid, r_case_number, r_charge_degree, r_days_from_arrest, r_offense_date, r_charge_desc, r_jail_in, r_jail_out, violent_recid, is_violent_recid, vr_case_number, vr_charge_degree, vr_offense_date, vr_charge_desc, type_of_assessment, decile_score.1, score_text, screening_date, v_type_of_assessment, v_decile_score, v_score_text, v_screening_date, in_custody, out_custody, priors_count.1, start, end, event, two_year_recid]
# Index: []
#
# [0 rows x 53 columns]

# %%
temp_df[ temp_df['score_text'] == 'N/A']
# Out:
# Empty DataFrame
# Columns: [id, name, first, last, compas_screening_date, sex, dob, age, age_cat, race, juv_fel_count, decile_score, juv_misd_count, juv_other_count, priors_count, days_b_screening_arrest, c_jail_in, c_jail_out, c_case_number, c_offense_date, c_arrest_date, c_days_from_compas, c_charge_degree, c_charge_desc, is_recid, r_case_number, r_charge_degree, r_days_from_arrest, r_offense_date, r_charge_desc, r_jail_in, r_jail_out, violent_recid, is_violent_recid, vr_case_number, vr_charge_degree, vr_offense_date, vr_charge_desc, type_of_assessment, decile_score.1, score_text, screening_date, v_type_of_assessment, v_decile_score, v_score_text, v_screening_date, in_custody, out_custody, priors_count.1, start, end, event, two_year_recid]
# Index: []
#
# [0 rows x 53 columns]

# %%
 temp_df[(temp_df['score_text'] != 'Medium' ) &  (temp_df['score_text'] != 'High' ) & (temp_df['score_text'] != 'Low' ) ]
# Out:
# Empty DataFrame
# Columns: [id, name, first, last, compas_screening_date, sex, dob, age, age_cat, race, juv_fel_count, decile_score, juv_misd_count, juv_other_count, priors_count, days_b_screening_arrest, c_jail_in, c_jail_out, c_case_number, c_offense_date, c_arrest_date, c_days_from_compas, c_charge_degree, c_charge_desc, is_recid, r_case_number, r_charge_degree, r_days_from_arrest, r_offense_date, r_charge_desc, r_jail_in, r_jail_out, violent_recid, is_violent_recid, vr_case_number, vr_charge_degree, vr_offense_date, vr_charge_desc, type_of_assessment, decile_score.1, score_text, screening_date, v_type_of_assessment, v_decile_score, v_score_text, v_screening_date, in_custody, out_custody, priors_count.1, start, end, event, two_year_recid]
# Index: []
#
# [0 rows x 53 columns]
